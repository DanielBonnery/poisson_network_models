# %% [markdown]
# # Prior

# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd

import os
os.chdir('../../../..')
print(os.getcwd())
# Out:
# c:\Users\Paul\Documents\X\4A\S1\HMM\poisson_network_models

# %%
from src.smc_2324_project.simulate.generate_dataset import *
from src.smc_2324_project.tempering.base_dist import *
from src.smc_2324_project.tempering.tempering import *

from src.smc_2324_project.variational.posterior_gamma import hessian, sample_from_gamma
from src.smc_2324_project.variational.posterior_nu import sample_from_nu
from src.smc_2324_project.variational.SBM_regression import VEM

# %% [markdown]
# # Dataset

# %%
# import
net = pd.read_excel('data/tree_network.xlsx',sheet_name="tree_network")
taxo_dist = pd.read_excel('data/tree_network.xlsx',sheet_name="taxo_dist_tree")
gen_dist = pd.read_excel('data/tree_network.xlsx',sheet_name="genetic_dist")
geo_dist = pd.read_excel('data/tree_network.xlsx',sheet_name="geo_dist")

# %%
# preprocess
net.set_index('Unnamed: 0',inplace=True)
taxo_dist.set_index('Unnamed: 0',inplace=True)
gen_dist.set_index('Unnamed: 0',inplace=True)
geo_dist.set_index('Unnamed: 0',inplace=True)

# %%
tree_net
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 tree_net
#
# NameError: name 'tree_net' is not defined

# %%
tree_ids = list(net.columns)[:-1]
tree_net = net.loc[tree_ids]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 2
#       1 tree_ids = list(net.columns)[:-1]
# ----> 2 tree_net = net.loc[tree_ids]
#
# File c:\Users\Paul\.conda\envs\hmm\Lib\site-packages\pandas\core\indexing.py:1153, in _LocationIndexer.__getitem__(self, key)
#    1150 axis = self.axis or 0
#    1152 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1153 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\Paul\.conda\envs\hmm\Lib\site-packages\pandas\core\indexing.py:1382, in _LocIndexer._getitem_axis(self, key, axis)
#    1379     if hasattr(key, "ndim") and key.ndim > 1:
#    1380         raise ValueError("Cannot index with multidimensional key")
# -> 1382     return self._getitem_iterable(key, axis=axis)
#    1384 # nested tuple slicing
#    1385 if is_nested_tuple(key, labels):
#
# ...

# %%
net
# Out:
#             ABIEALB  ABIEGRA  ABIENOR  ACERGRA  ACERPET  ALNUGLU  BETUSPP  \
# Unnamed: 0
# AMPHLEI           0        0        0        0        0        0        0
# APIOERR           0        0        0        1        0        0        0
# APIOVEN           0        0        0        0        0        0        0
# ARMICEP           0        1        0        1        0        0        0
# ARMIGAL           1        1        1        1        1        1        0
# ...             ...      ...      ...      ...      ...      ...      ...
# VENTFRA           0        0        0        0        0        0        0
# VENTINA           0        0        0        0        0        0        0
# VERTDAH           0        0        0        1        1        0        0
# ZYTHPIN           0        0        0        0        0        0        0
# NB_INTER_A       17       16       11       23        5        7        1
#
# ...
